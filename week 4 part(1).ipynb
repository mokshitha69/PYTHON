# %%
# Lists
fruits = ["apple", "banana", "cherry", "apple"]
print("Original List:", fruits)
fruits.append("orange")
print(fruits)
if "banana" in fruits:
  fruits.remove("banana")
print(fruits)
print("First fruit:", fruits[-1])
upper_fruits = [fruit.upper() for fruit in fruits]
print("Uppercase Fruits:", upper_fruits)
# Out:
# Original List: ['apple', 'banana', 'cherry', 'apple']
# ['apple', 'banana', 'cherry', 'apple', 'orange']
# ['apple', 'cherry', 'apple', 'orange']
# First fruit: orange
# Uppercase Fruits: ['APPLE', 'CHERRY', 'APPLE', 'ORANGE']

# %%
# Tuples
coordinates= (10.5, 20.3, 10.5)
print("Tuple:", coordinates)
print("First coordinate:", coordinates[-2])
x, y, z = coordinates
print(f"Unpacked: x={x}, y={y}, z={z}")
# Out:
# Tuple: (10.5, 20.3, 10.5)
# First coordinate: 20.3
# Unpacked: x=10.5, y=20.3, z=10.5

# %%
# Create a list of 5 numbers and print all elements
num = [1, 2, 3, 4, 5]
print(num)
# Out:
# [1, 2, 3, 4, 5]

# %%
# Print first and last element of a list[10, 20, 30, 40, 50]
my_list = [10, 20, 30, 40, 50]
print("First element:", my_list[0])
print("Last element:", my_list[-1])
# Out:
# First element: 10
# Last element: 50

# %%
# Add number 100 to yhe list [1, 2, 3, 4]
my_list = [1, 2, 3, 4]
my_list.append(100)
print(my_list)
# Out:
# [1, 2, 3, 4, 100]

# %%
# Remove element 3 from the list[1, 2, 3, 4, 5]
my_list = [1, 2, 3, 4, 5]
my_list.remove(3)
print(my_list)
# Out:
# [1, 2, 4, 5]

# %%
# Find the sum of all elements in [5, 10, 15, 20]
my_list = [5, 10, 15, 20]
total = sum(my_list)
print("Sum =", total)
# Out:
# Sum = 50

# %%
# Find the maximun and minimum in [8, 3, 9, 1, 6]
my_list = [8, 3, 9, 1, 6]
# Find maximum and minimum
maximum = max(my_list)
minimum = min(my_list)
print("Maximum =", maximum)
print("Minimum =", minimum)
# Out:
# Maximum = 9
# Minimum = 1

# %%
# Creeate a tuple of 4 elements and print it
my_tuple = (10, 20, 30, 40)
print(my_tuple)
# Out:
# (10, 20, 30, 40)

# %%
# Print second and third element of tuple (10, 20, 30, 40)
my_tuple = (10, 20, 30, 40)
print("Second element:", my_tuple[1])
print("Third element:", my_tuple[2])
# Out:
# Second element: 20
# Third element: 30

# %%
# Unpack tuple (5, 10, 15) into variables and print them
my_tuple = (5, 10, 15)
# Unpack tuple
a, b, c = my_tuple
print(a)
print(b)
print(c)
# Out:
# 5
# 10
# 15
